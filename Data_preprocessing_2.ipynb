# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('gurgoan_properties.csv')

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.sample(5)
# Out:
#                                 property_name property_type  \
# 206           3 BHK Flat in Sector 48 Gurgaon          flat
# 3306          2 BHK Flat in Sector 86 Gurgaon          flat
# 1020          3 BHK Flat in Sector 67 Gurgaon          flat
# 586   8 Bedroom House for sale in DLF Phase 1         house
# 250                       2 BHK Flat in Sohna          flat
#
#                      society  price  price_per_sqft    area  \
# 206   bestech park view city   1.78         10022.0  1776.0
# 3306        ansal heights 86   0.78          5735.0  1360.0
# 1020              m3m merlin   3.50         14843.0  2358.0
# 586              independent   6.00         33333.0  1800.0
# 250   breez global hill view   0.35          5319.0   658.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 206   Super Built up area 1776(165 sq.m.)Carpet area...        3         4
# 3306                 Built Up area: 1360 (126.35 sq.m.)        2         2
# 1020             Super Built up area 2358(219.07 sq.m.)        3         4
# 586                         Plot area 200(167.23 sq.m.)        8         5
# 250   Built Up area: 658 (61.13 sq.m.)Carpet area: 5...        2         2
#
#      balcony         additionalRoom  \
# 206        2  study room,pooja room
# 3306       2          not available
# 1020      3+           servant room
# 586       3+          not available
# 250        2          not available
#
#                                                 address  floorNum facing  \
# 206                 Sector 48 Gurgaon, Gurgaon, Haryana       5.0    NaN
# 3306       Tower I, Sector 86 Gurgaon, Gurgaon, Haryana       8.0  North
# 1020  Middle Floor, Sector 67 Gurgaon, Gurgaon, Haryana      15.0  South
# 586                       DLF Phase 1, Gurgaon, Haryana       3.0    NaN
# 250                       1803, Sohna, Gurgaon, Haryana      18.0    NaN
#
#         agePossession                                    nearbyLocations  \
# 206   1 to 5 Year Old  ['Rapid Metro Sector 56', 'Sapphire Mall', 'Om...
# 3306  0 to 1 Year Old  ['IRIS Broadway Mall', 'Delhi Jaipur Expresswa...
# 1020  1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 586      10+ Year Old  ['Guru dronacharya metro station', 'Dlf phase ...
# 250   0 to 1 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
#
#                                             description  \
# 206   Looking for a 3 bhk property for sale in gurga...
# 3306  Park facing north facing unit - 8th floor. Pos...
# 1020  M3m merlin is one of gurgaon's most sought aft...
# 586   Interested to sell independent house/villa.It ...
# 250   This beautiful property located in the heart o...
#
#                                          furnishDetails  \
# 206                                                 NaN
# 3306                                                NaN
# 1020  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 586   ['8 Bed', '8 Wardrobe', '5 Geyser', '10 AC', '...
# 250   ['3 Fan', '6 Light', 'No AC', 'No Bed', 'No Ch...
#
#                                                features  \
# 206   ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 3306  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1020  ['Centrally Air Conditioned', 'Security / Fire...
# 586                        ['Private Garden / Terrace']
# 250   ['Power Back-up', 'Lift(s)', 'Park', 'Shopping...
#
#                                                  rating
# 206   ['Green Area5 out of 5', 'Construction4 out of...
# 3306  ['Safety4.5 out of 5', 'Lifestyle5 out of 5', ...
# 1020  ['Green Area4 out of 5', 'Construction4 out of...
# 586   ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 250   ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head(1)
# Out:
#                      property_name property_type         society  price  \
# 0  3 BHK Flat in Sector 83 Gurgaon          flat  vatika gurgaon   1.25
#
#    price_per_sqft    area                            areaWithType  bedRoom  \
# 0          6313.0  1980.0  Super Built up area 1980(183.95 sq.m.)        3
#
#    bathroom balcony additionalRoom                                    address  \
# 0         3       2   servant room  1024, Sector 83 Gurgaon, Gurgaon, Haryana
#
#    floorNum facing    agePossession  \
# 0       2.0   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
#
#                                          description furnishDetails  \
# 0  Looking for a 3 bhk property for sale in gurga...            NaN
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4.5 out ...

# %%
df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip().head(5)
# Out:
# 0                  Sector 83
# 1    New Palam Vihar Phase 1
# 2                 Sector 106
# 3                 Sector 102
# 4                  Sector 69
# Name: property_name, dtype: object

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head(1)
# Out:
#                      property_name property_type         society     sector  \
# 0  3 BHK Flat in Sector 83 Gurgaon          flat  vatika gurgaon  Sector 83
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   1.25          6313.0  1980.0  Super Built up area 1980(183.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# 0        3         3       2   servant room
#
#                                      address  floorNum facing  \
# 0  1024, Sector 83 Gurgaon, Gurgaon, Haryana       2.0   West
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
#
#                                          description furnishDetails  \
# 0  Looking for a 3 bhk property for sale in gurga...            NaN
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4.5 out ...

# %%
df['sector'] = df['sector'].str.lower()

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts()>=3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 575   2 BHK Flat in New Gurgaon          flat                   green court
# 1286  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2131  4 BHK Flat in New Gurgaon          flat                    sare homes
# 2387  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft    area  \
# 575     new   0.38          5507.0   690.0
# 1286    new   4.00         11428.0  3500.0
# 2131    new   0.85          4786.0  1776.0
# 2387    new   0.67          5583.0  1200.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 575            Carpet area: 690 (64.1 sq.m.)        2         2       1
# 1286        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 2131     Super Built up area 1776(165 sq.m.)        4         4       3
# 2387  Super Built up area 1200(111.48 sq.m.)        2         2       2
#
#                additionalRoom                        address  floorNum facing  \
# 575             not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
# 1286  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 2131            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 2387            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 575   Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 1286            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2131    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 2387     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 575   We are the proud owners of this 2 bhk apartmen...
# 1286  This lovely 4 bhk apartment/flat in new gurgao...
# 2131  Located in the popular residential address of ...
# 2387  Check out this 2 bhk apartment for sale in tak...
#
#                                          furnishDetails  \
# 575                                                  []
# 1286  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2131                                                 []
# 2387                                                 []
#
#                                                features rating
# 575   ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 1286  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2131                                                NaN    NaN
# 2387  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 547                 2 BHK Flat in New Palam Vihar          flat
# 767                 2 BHK Flat in New Palam Vihar          flat
# 774                 2 BHK Flat in New Palam Vihar          flat
# 3326  3 Bedroom House for sale in New Palam Vihar         house
# 3777  2 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 547   ompee k s residency  new sector 2   1.60         26936.0   594.0
# 767               my home  new sector 2   0.22          4400.0   500.0
# 774               my home  new sector 2   0.28          3166.0   884.0
# 3326          independent  new sector 2   1.00          8796.0  1137.0
# 3777              my home  new sector 2   0.34         12592.0   270.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 547                       Carpet area: 66 (55.18 sq.m.)        2         2
# 767                      Carpet area: 500 (46.45 sq.m.)        2         2
# 774                      Carpet area: 900 (83.61 sq.m.)        2         1
# 3326  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 3777                         Plot area 270(25.08 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 547        2  not available
# 767        1  not available
# 774        1         others
# 3326       2     pooja room
# 3777       2  not available
#
#                                                 address  floorNum facing  \
# 547                   New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 767                   New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 774          F 150/b, New Palam Vihar, Gurgaon, Haryana       2.0    NaN
# 3326  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...       1.0  North
# 3777         Ez-19 A, New Palam Vihar, Gurgaon, Haryana       3.0   West
#
#          agePossession                                    nearbyLocations  \
# 547    1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 767    0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 774    1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3326      10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3777  5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 547   We are the proud owners of this 2 bhk apartmen...
# 767   Cctv surveillance are provided here. There is ...
# 774   2 bhk room with wooden coverd ,1 drawing room,...
# 3326  Ground and first floor, Ground floor: Ground f...
# 3777  There are availability of various facilities l...
#
#                                          furnishDetails  \
# 547                                                 NaN
# 767   ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 774   ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 3326                                                NaN
# 3777  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
#
#                                           features  \
# 547                                            NaN
# 767                                            NaN
# 774                      ['Water Storage', 'Park']
# 3326                                           NaN
# 3777  ['Water Storage', 'Park', 'Visitor Parking']
#
#                                                  rating
# 547   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 767   ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 774   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3326  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3777  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
